# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
songs = pd.read_csv('data/songs.csv')

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12065 entries, 0 to 12064
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            12065 non-null  object
#  1   album             12065 non-null  object
#  2   release_date      12065 non-null  object
#  3   track_name        12065 non-null  object
#  4   track_id          12065 non-null  object
#  5   popularity        12065 non-null  int64
#  6   danceability      12065 non-null  float64
#  7   energy            12065 non-null  float64
#  8   key               12065 non-null  int64
#  9   loudness          12065 non-null  float64
#  10  mode              12065 non-null  int64
#  11  speechiness       12065 non-null  float64
#  12  instrumentalness  12065 non-null  float64
#  13  liveness          12065 non-null  float64
#  14  valence           12065 non-null  float64
#  15  tempo             12065 non-null  float64
#  16  duration_ms       12065 non-null  int64
#  17  time_signature    12065 non-null  int64
#  18  hit               2065 non-null   float64
# dtypes: float64(9), int64(5), object(5)
# memory usage: 1.7+ MB

# %% [markdown]
# Drop duplicate tracks from the merged playlists and fill NaN values in the hit column in order to binarize the column

# %%
songs.drop_duplicates(subset=['track_name','artist'], inplace=True)
songs['hit'] = songs['hit'].fillna(int(0))
songs['hit'] = songs['hit'].astype(int)

# %% [markdown]
# Create new features that examine the day and month a track was released

# %%
songs['release_date'] = pd.to_datetime(songs['release_date'])
songs['release_day'] = songs['release_date'].apply(lambda x: x.day)
songs['release_month'] = songs['release_date'].apply(lambda x: x.month)
songs['release_year'] = songs['release_date'].apply(lambda x: x.year)

# %%
#songs = songs[(songs['release_date'].dt.year >=2010)]

# %%
songs['hit'].value_counts()
# Out:
# 0    8596
# 1    1889
# Name: hit, dtype: int64

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10485 entries, 0 to 12064
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            10485 non-null  object
#  1   album             10485 non-null  object
#  2   release_date      10485 non-null  datetime64[ns]
#  3   track_name        10485 non-null  object
#  4   track_id          10485 non-null  object
#  5   popularity        10485 non-null  int64
#  6   danceability      10485 non-null  float64
#  7   energy            10485 non-null  float64
#  8   key               10485 non-null  int64
#  9   loudness          10485 non-null  float64
#  10  mode              10485 non-null  int64
#  11  speechiness       10485 non-null  float64
#  12  instrumentalness  10485 non-null  float64
#  13  liveness          10485 non-null  float64
#  14  valence           10485 non-null  float64
#  15  tempo             10485 non-null  float64
#  16  duration_ms       10485 non-null  int64
#  17  time_signature    10485 non-null  int64
#  18  hit               10485 non-null  int32
#  19  release_day       10485 non-null  int64
#  20  release_month     10485 non-null  int64
#  21  release_year      10485 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int32(1), int64(8), object(4)
# memory usage: 1.8+ MB

# %%
songs.columns[6:18]
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature'],
#       dtype='object')

# %%
songs.describe().T
# Out:
#                     count           mean           std          min  \
# popularity        10485.0      33.246447     28.154933      0.00000
# danceability      10485.0       0.607766      0.158946      0.07090
# energy            10485.0       0.705351      0.200242      0.00289
# key               10485.0       5.328946      3.602990      0.00000
# loudness          10485.0      -6.638438      3.283409    -39.76500
# mode              10485.0       0.619456      0.485544      0.00000
# speechiness       10485.0       0.088216      0.088208      0.02190
# instrumentalness  10485.0       0.089042      0.225691      0.00000
# liveness          10485.0       0.193085      0.158122      0.01200
# valence           10485.0       0.511507      0.240226      0.02620
# tempo             10485.0     122.766623     27.320473     43.79000
# duration_ms       10485.0  228366.785503  49263.033767  63390.00000
# time_signature    10485.0       3.966619      0.274212      1.00000
# hit               10485.0       0.180162      0.384341      0.00000
# release_day       10485.0      12.877444      9.790945      1.00000
# release_month     10485.0       5.554602      3.653016      1.00000
# release_year      10485.0    2009.467525     10.236605   1936.00000
#
#                           25%            50%           75%         max
# popularity             0.0000      35.000000      59.00000      91.000
# danceability           0.5020       0.616000       0.72300       0.980
# energy                 0.5830       0.741000       0.86600       0.999
# key                    2.0000       6.000000       8.00000      11.000
# loudness              -7.9300      -5.889000      -4.48800       0.654
# mode                   0.0000       1.000000       1.00000       1.000
# speechiness            0.0368       0.053000       0.09640       0.940
# instrumentalness       0.0000       0.000036       0.00857       0.992
# liveness               0.0929       0.128000       0.25400       0.984
# valence                0.3280       0.508000       0.70100       0.990
# tempo                101.8070     122.987000     138.05700     217.531
# duration_ms       196267.0000  223112.000000  255566.00000  688453.000
# time_signature         4.0000       4.000000       4.00000       5.000
# hit                    0.0000       0.000000       0.00000       1.000
# release_day            2.0000      12.000000      21.00000      31.000
# release_month          2.0000       5.000000       9.00000      12.000
# release_year        2006.0000    2013.000000    2016.00000    2021.000

# %%
plt.figure(figsize=(8,6))
sns.histplot(songs, x='release_day', hue='hit',bins=35)
plt.xticks(np.arange(0, 31, 1))
plt.title('Dancebility', fontsize=20);

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))

fig.suptitle('Distribution of ')

sns.boxplot(ax=axes[0, 0], data=songs, x='hit', y='danceability')
sns.boxplot(ax=axes[0, 1], data=songs, x='hit', y='energy')
sns.boxplot(ax=axes[0, 2], data=songs, x='hit', y='key')
sns.boxplot(ax=axes[1, 0], data=songs, x='hit', y='loudness')
#sns.boxplot(ax=axes[1, 1], data=songs, x='hit', y='mode')
sns.boxplot(ax=axes[1, 1], data=songs, x='hit', y='speechiness')
sns.boxplot(ax=axes[1, 2], data=songs, x='hit', y='liveness')
sns.boxplot(ax=axes[2, 0], data=songs, x='hit', y='valence')
sns.boxplot(ax=axes[2, 1], data=songs, x='hit', y='tempo')
sns.boxplot(ax=axes[2, 2], data=songs, x='hit', y='duration_ms')
#sns.boxplot(ax=axes[3, 0], data=songs, x='hit', y='time_signature')
# Out:
# <AxesSubplot:xlabel='hit', ylabel='duration_ms'>

# %%
for col in songs.columns[6:18]:
    plt.figure(figsize=(8,6))
    sns.histplot(data=songs, x=col, hue='hit')
    plt.title(f'{col.capitalize()}', fontsize=20)
    plt.show()

# %%
audio_features=['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness','instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms','time_signature']

# %%
plt.figure(figsize=(20,10))
corr = songs[audio_features].corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, vmin=-1, vmax=1, square=True, linewidths=.5, mask=mask, annot=True);

# %%
songs[['artist','track_name','release_date','popularity','hit']].sort_values('popularity', ascending=False).head(20)
# Out:
#                   artist                                track_name  \
# 1984        Harry Styles                          Watermelon Sugar
# 1439   The Neighbourhood                           Sweater Weather
# 1969              DaBaby              ROCKSTAR (feat. Roddy Ricch)
# 1891       Lewis Capaldi                         Someone You Loved
# 1926         Post Malone                                   Circles
# 1988             Cardi B           WAP (feat. Megan Thee Stallion)
# 9802       Billie Eilish                      lovely (with Khalid)
# 1732        Travis Scott                                goosebumps
# 1983           SAINt JHN                     Roses - Imanbek Remix
# 2013           Pop Smoke   For The Night (feat. Lil Baby & DaBaby)
# 10497              Topic                               Breaking Me
# 2011            24kGoldn                    Mood (feat. iann dior)
# 1868       Billie Eilish                                   bad guy
# 1967         Roddy Ricch                                   The Box
# 1972            Maroon 5                                  Memories
# 2007               Powfu          death bed (coffee for your head)
# 2005               Drake      Laugh Now Cry Later (feat. Lil Durk)
# 1675        James Arthur                      Say You Won't Let Go
# 716     Gym Class Heroes  Cupid's Chokehold / Breakfast in America
# 1970        Harry Styles                                 Adore You
#
#       release_date  popularity  hit
# 1984    2019-12-13          91    1
# 1439    2013-04-19          89    1
# 1969    2020-04-17          89    1
# 1891    2019-05-17          89    1
# 1926    2019-09-06          88    1
# 1988    2020-08-07          88    1
# 9802    2018-04-19          88    0
# 1732    2016-09-16          87    1
# 1983    2019-10-09          87    1
# 2013    2020-07-03          87    1
# 10497   2019-12-19          87    0
# 2011    2020-07-24          87    1
# 1868    2019-03-29          87    1
# 1967    2019-12-06          87    1
# 1972    2019-09-20          87    1
# 2007    2020-02-08          87    1
# 2005    2020-08-14          87    1
# 1675    2016-10-28          86    1
# 716     2005-02-22          86    1
# 1970    2019-12-13          86    1

# %%
songs.to_csv('data/songs_clean.csv', index=False)
